# %%
from scripts.majestic import parse_majestic_csv
from scripts.whois import get_whois_data

majestic = '../../data/raw/majestic_million_small.csv'
domains = '../../data/raw/majestic_domains.txt'
destfile = '../../data/raw/benign_whois_data.txt'

# %%
parse_majestic_csv(majestic, domains)

# %%
get_whois_data(domains, destfile, start_at=1480)
# Out:
# Total domains: 10000
# 1480; alipay.com; using  alipay.com; {
#   "domain_name": [
#     "ALIPAY.COM",
#     "alipay.com"
#   ],
#   "registrar": "Alibaba Cloud Computing (Beijing) Co., Ltd.",
#   "whois_server": "grs-whois.hichina.com",
#   "referral_url": null,
#   "updated_date": "2021-08-24 12:57:59",
#   "creation_date": "2004-10-08 10:44:53",
#   "expiration_date": "2023-10-08 10:44:53",
#   "name_servers": [
#     "NS1.ALIPAY.COM",
#     "NS2.ALIPAY.COM",
#     "NS3.ALIPAY.COM",
#     "NS4.ALIPAY.COM"
#   ],
#   "status": [
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited",
#     "serverTransferProhibited https://icann.org/epp#serverTransferProhibited",
#     "serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited"
#   ],
#   "emails": "DomainAbuse@service.aliyun.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
# ...

# %%
print("stopped")
